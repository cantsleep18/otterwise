# %% [markdown]
# # Sample Analysis

# %%
import pandas as pdimport numpy as npdf = pd.read_csv('/mnt/c/Allround/otterwise/tests/fixtures/sample-dataset.csv')print(f'Dataset loaded: {df.shape[0]} rows x {df.shape[1]} columns')df.head()
# Out:
# Dataset loaded: 20 rows x 10 columns

# %%
df.describe()
# Out:
#               id    revenue  units_sold       price    discount  customer_age  satisfaction_scorecount  20.000000  19.000000   20.000000   20.000000   20.000000     20.000000          19.000000mean   10.500000  614.590526    4.900000  288.318500    0.062500     40.450000           4.047368

# %%
import matplotlib.pyplot as pltdf.groupby('category')['revenue'].sum().plot(kind='bar')plt.title('Revenue by Category')plt.tight_layout()plt.show()
